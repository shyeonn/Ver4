# %%
from unittest import FunctionTestCase
import pandas as pd
import numpy as np


Function = ['Copy', 'Scale', 'Add', 'Triad']
Channel_num = ['1', '2', '4', '8', '16']
values = np.empty(shape=(4,5))



def check_string():
    i = 0
    j = 0
    for channel_num in Channel_num:
        with open(channel_num +'channel.txt') as temp_f:
            datafile = temp_f.readlines()
        for line in datafile:
            for name in Function:
                if name in line:
                    print(line)
                    values[j][i] = line[16:23]
                    j = j+1
                    
        i = i+1
        j = 0

check_string()
# Out:
# Copy:            1186.7     0.013484     0.013483     0.013485
#
# Scale:            639.5     0.025020     0.025019     0.025020
#
# Add:              677.1     0.035447     0.035447     0.035447
#
# Triad:            658.3     0.036456     0.036456     0.036456
#
# Copy:            1218.7     0.013129     0.013129     0.013129
#
# Scale:            640.6     0.024979     0.024977     0.024980
#
# Add:              677.1     0.035446     0.035445     0.035447
#
# Triad:            661.2     0.036300     0.036298     0.036302
#
# Copy:            1219.9     0.013117     0.013116     0.013117
#
# Scale:            640.3     0.025025     0.024987     0.025080
#
# Add:              669.0     0.035888     0.035876     0.035894
#
# Triad:            662.5     0.036227     0.036226     0.036229
#
# Copy:            1220.7     0.013110     0.013107     0.013112
#
# Scale:            641.1     0.024958     0.024957     0.024959
#
# Add:              668.8     0.035939     0.035883     0.036012
#
# Triad:            660.3     0.036406     0.036347     0.036441
#
# Copy:            1228.7     0.013034     0.013022     0.013042
#
# Scale:            651.3     0.024594     0.024566     0.024622
#
# Add:              691.7     0.034699     0.034699     0.034700
#
# Triad:            675.2     0.035547     0.035546     0.035547

# %%
df = pd.DataFrame(values, index=Function, columns=Channel_num)
average = df.mean()
df.plot()
# Out:
# <AxesSubplot:>

# %%
#average.plot(title = 'CPU1', xlable='Num_Channel', y= 'Bandwidth_avarage')
ax= average.plot(title='TimingsimpleCPU / 1_core / l1_cache / no_openMP / memmove')
ax.set_xlabel("HBM channel#")
ax.set_ylabel("BW (MB/s)")
# Out:
# Text(0, 0.5, 'BW (MB/s)')

# %%
import os
mypath = os.getcwd()

splitpath = os.path.split(mypath)
print(splitpath)
average.to_csv('../Average/test{splitpath[1]}.csv')
# Out:
# ('/workspaces/bootcamp-assignment-shyeonn/Ver4/result/HBM_compare', 'test5')
