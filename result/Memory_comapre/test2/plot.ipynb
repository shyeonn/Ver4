# %%
from unittest import FunctionTestCase
import pandas as pd
import numpy as np


Function = ['Copy', 'Scale', 'Add', 'Triad']
MemName = ['DDR4_2400_16x4', 'GDDR5_4000_2x32', 'HBM_2000_4H_1x64']
values = np.empty(shape=(4,3))



def check_string():
    i = 0
    j = 0
    for Name in MemName:
        with open('result_' + Name + '.txt') as temp_f:
            datafile = temp_f.readlines()
        for line in datafile:
            for name in Function:
                if name in line:
                    print(line)
                    values[j][i] = line[16:23]
                    j = j+1
                    
        i = i+1
        j = 0

check_string()
# Out:
# Copy:            9211.3     0.001738     0.001737     0.001739
#
# Scale:           9774.1     0.001638     0.001637     0.001639
#
# Add:            11489.3     0.002094     0.002089     0.002099
#
# Triad:          11571.8     0.002076     0.002074     0.002077
#
# Copy:            9014.0     0.001786     0.001775     0.001797
#
# Scale:           9709.0     0.001711     0.001648     0.001775
#
# Add:            12054.0     0.001997     0.001991     0.002003
#
# Triad:          11870.0     0.002023     0.002022     0.002024
#
# Copy:            8714.9     0.001853     0.001836     0.001870
#
# Scale:           8903.9     0.001836     0.001797     0.001875
#
# Add:            10685.6     0.002279     0.002246     0.002312
#
# Triad:          10801.4     0.002237     0.002222     0.002253

# %%
df = pd.DataFrame(values, index=Function, columns=MemName)
print(df)
# Out:
#        DDR4_2400_16x4  GDDR5_4000_2x32  HBM_2000_4H_1x64
# Copy           9211.3           9014.0            8714.9
# Scale          9774.1           9709.0            8903.9
# Add           11489.3          12054.0           10685.6
# Triad         11571.8          11870.0           10801.4

# %%
df.plot()
dfT=df.transpose()
dfT.plot.bar(stacked = True, width=0.3)
# Out:
# <AxesSubplot:>

# %%
import os
mypath = os.getcwd()
splitpath = os.path.split(mypath)
path = '../All/' + splitpath[1] + '.csv'

# %%
average = df.mean()
average.to_csv(path)
