# %%
from unittest import FunctionTestCase
import pandas as pd
import numpy as np


Function = ['Copy', 'Scale', 'Add', 'Triad']
MemName = ['DDR4_2400_16x4', 'GDDR5_4000_2x32', 'HBM_2000_4H_1x64']
values = np.empty(shape=(4,3))



def check_string():
    i = 0
    j = 0
    for Name in MemName:
        with open('result_' + Name + '.txt') as temp_f:
            datafile = temp_f.readlines()
        for line in datafile:
            for name in Function:
                if name in line:
                    print(line)
                    values[j][i] = line[16:23]
                    j = j+1
                    
        i = i+1
        j = 0

check_string()
# Out:
# Copy:           11457.4     0.002805     0.002793     0.002817
#
# Scale:          11263.7     0.002846     0.002841     0.002851
#
# Add:            11673.1     0.004148     0.004112     0.004183
#
# Triad:          11613.9     0.004142     0.004133     0.004150
#
# Copy:           11291.6     0.002861     0.002834     0.002888
#
# Scale:          11726.2     0.002744     0.002729     0.002760
#
# Add:            11781.8     0.004093     0.004074     0.004111
#
# Triad:          11949.2     0.004045     0.004017     0.004074
#
# Copy:            9512.2     0.003374     0.003364     0.003383
#
# Scale:          10142.7     0.003188     0.003155     0.003220
#
# Add:            10443.9     0.004599     0.004596     0.004603
#
# Triad:          10455.0     0.004627     0.004591     0.004662

# %%
df = pd.DataFrame(values, index=Function, columns=MemName)
print(df)
# Out:
#        DDR4_2400_16x4  GDDR5_4000_2x32  HBM_2000_4H_1x64
# Copy          11457.4          11291.6            9512.2
# Scale         11263.7          11726.2           10142.7
# Add           11673.1          11781.8           10443.9
# Triad         11613.9          11949.2           10455.0

# %%
df.plot()
dfT=df.transpose()
dfT.plot.bar(stacked = True, width=0.3)
# Out:
# <AxesSubplot:>

# %%
import os
mypath = os.getcwd()
splitpath = os.path.split(mypath)
path = '../All/' + splitpath[1] + '.csv'

# %%
average = df.mean()
average.to_csv(path)
